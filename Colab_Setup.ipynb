# %% [markdown]
# # Google Colab Setup: House Price Prediction Dataset Download
#
# Run this cell first to download and extract the data from GitHub

# %%
# Method 1: Clone repository directly in Colab
# !git clone https://github.com/opbiswal12-dev/house_price_prediction.git
# !cd house_price_prediction && unzip -o train.csv.zip && unzip -o test.csv.zip

import os
import shutil

# Move CSV files to root directory for easy access
shutil.move('house_price_prediction/train.csv', 'train.csv')
shutil.move('house_price_prediction/test.csv', 'test.csv')
shutil.move('house_price_prediction/sample_submission.csv', 'sample_submission.csv')

print("✓ Files downloaded and extracted successfully!")
print(f"\nFiles in current directory:")
print(os.listdir())

# %% [markdown]
# # Verify Data Files

# %%
import pandas as pd
import numpy as np

# Load and verify files
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

print("✓ Data loaded successfully!")
print(f"\nTraining data shape: {train_df.shape}")
print(f"Test data shape: {test_df.shape}")
print(f"\nFirst few rows of training data:")
train_df.head()

# %% [markdown]
# # Now run the main notebook code below
#
# Copy all cells from the main House_Price_Prediction.ipynb starting from "Step 0: Import Required Libraries"
